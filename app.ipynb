# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: dash==1.0.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: dash-bootstrap-components in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: dash-core-components in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: dash-html-components in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: dash-renderer in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: dash-table in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pandas==1.3.4 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.3.4)
# Requirement already satisfied: plotly==5.5.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (5.5.0)
# Requirement already satisfied: numpy==1.20.3 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.20.3)
# Requirement already satisfied: openpyxl in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (3.0.9)
# Requirement already satisfied: pytest in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (6.2.5)
# Requirement already satisfied: lxml in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: selenium in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: percy in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pytest-sugar in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (0.9.4)
# Requirement already satisfied: requests[security] in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: pytest-mock in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: Flask>=0.12 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: waitress in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: flask-compress in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from dash==1.0.0->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pandas==1.3.4->-r requirements.txt (line 7)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pandas==1.3.4->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from plotly==5.5.0->-r requirements.txt (line 8)) (8.0.1)
# Requirement already satisfied: six in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from plotly==5.5.0->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: et-xmlfile in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from openpyxl->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from Flask>=0.12->dash==1.0.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from Flask>=0.12->dash==1.0.0->-r requirements.txt (line 1)) (8.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from Flask>=0.12->dash==1.0.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from Flask>=0.12->dash==1.0.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from Jinja2>=3.0->Flask>=0.12->dash==1.0.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from beautifulsoup4->dash==1.0.0->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: brotli in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from flask-compress->dash==1.0.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: py>=1.8.2 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: toml in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: iniconfig in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: packaging in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest->dash==1.0.0->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from packaging->pytest->dash==1.0.0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from pytest-sugar->dash==1.0.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from selenium->dash==1.0.0->-r requirements.txt (line 1)) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from selenium->dash==1.0.0->-r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from trio~=0.17->selenium->dash==1.0.0->-r requirements.txt (line 1)) (1.10)
# Requirement already satisfied: outcome in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from trio~=0.17->selenium->dash==1.0.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: sortedcontainers in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from trio~=0.17->selenium->dash==1.0.0->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: sniffio in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from trio~=0.17->selenium->dash==1.0.0->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium->dash==1.0.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from urllib3<1.27,>=1.21.1->requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from urllib3<1.27,>=1.21.1->requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (35.0.0)
# Requirement already satisfied: cffi>=1.12 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3<1.27,>=1.21.1->requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (1.14.6)
# Requirement already satisfied: pycparser in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3<1.27,>=1.21.1->requests[security]->dash==1.0.0->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/edwardboamah/opt/anaconda3/envs/data_env/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->dash==1.0.0->-r requirements.txt (line 1)) (0.13.0)

# %%
#Import dependent libraries
import dash
import pandas as pd
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import numpy as np

import plotly.express as px

# %%
BA=pd.read_excel("exported data from Ahafo Region.xlsx")
AS=pd.read_excel("exported data from Ashanti Region.xlsx")
ES=pd.read_excel("Exported data from Eastern Region.xlsx")
GR=pd.read_excel("exported data from Greater Accra Region.xlsx")
ba = BA.iloc[:,0:12]
gr = GR.iloc[:,0:12]
ash = AS.iloc[:,0:12]
es = ES.iloc[:,0:12]
df = ba.append(ba).append(gr).append(ash).append(es)

# %%
nregions =df.Regions.unique()

# %%
#Choose a theme and define the layout
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
server = app.server

# %%
#the style arguments for the sidebar.
SIDEBAR_STYLE = {
     'position': 'fixed',
     'top': 0,
     'left': 0,
     'bottom': 0,
     'width': '20%',
     'padding': '20px 10px',
     'background-color': '#ffd697',
     
 }

# the style arguments for the main content page.
CONTENT_STYLE = {
     'margin-left': '25%',
     'margin-right': '5%',
     'padding': '20px 10p'
 }

TEXT_STYLE = {
     'textAlign': 'center',
     'color': '#191970'
 }

CARD_TEXT_STYLE = {
     'textAlign': 'center',
     'color': '#0074D9'
 }
#######Drop downs
controls = dbc.FormGroup(
     [
         html.Br(),
         html.P('Region', style={
             'textAlign': 'center'
         }),
         dcc.Dropdown(
             id='region-dropdown',
             
             options=[{"label": nr, "value": nr} for nr in np.sort(nregions)]
             ,
# default value
             multi=False
        
         ),
         html.Br(),
         html.P('District', style={
             'textAlign': 'center'
         }),
         dcc.Dropdown(
             id='district-dropdown',
# default value
             multi=False
         ),
         html.Br(),
         html.P('Indicators', style={
             'textAlign': 'center'
         }),
         dcc.Dropdown(
             id='indicators-dropdown',
             
             options=[
                 {"label": 'Age', "value": 'Age'},
                 {"label": 'Sex', "value": 'Sex'},
                 {"label": 'Education', "value": 'Education'}
                     ]
             ,
# default value
             multi=False
         ),
     ]
 )

sidebar = html.Div(
     [
         html.H2('Parameters', style=TEXT_STYLE),
         html.Hr(),
         controls
     ],
style=SIDEBAR_STYLE,
 )

# %%
# #Graph Items
content_third_row = dbc.Row(
     [
         html.Br(),
         html.P('What type of economic activity are you engaged in?', style={
             'textAlign': 'center'
         }),
         html.Br(),
  
        html.Div(
            children=dcc.Graph(
                id="type-chart"
            ),
            className="card",
            
        ),
     ]
 )

content_indicator_row = dbc.Row(
       [
          html.Br(),
         html.P('Are you engaged in any economic activity?', style={
             'textAlign': 'center'
         }),
           html.Br(),
           
        html.Div(
            children=dcc.Graph(
                id="eco-chart"
            ),
            className="card",
            
        ),
 
     ]
 )

content_secu_row = dbc.Row(
       [
          html.Br(),
         html.P('Would you describe the current security situation in the country as secured?', style={
             'textAlign': 'center'
         }),
           html.Br(),
        html.Div(
            children=dcc.Graph(
                id="secu-chart"
            ),
            className="card",
            
        ),

     ]
 )

content_con_row = dbc.Row(
       [
            html.Br(),
         html.P('Do you have confidence in the ability of security agencies to contain the security situation?',
                style={
             'textAlign': 'center'
         }),
    
        html.Div(
            children=dcc.Graph(
                id="con-chart"
            ),
            className="card",
            
        ),
      
     ]
 )

content_safe_row = dbc.Row(
       [
        html.Br(),
         html.P('Do you feel safe in the country?',
                style={
             'textAlign': 'center'
         }),
           html.Br(),
        html.Div(
            children=dcc.Graph(
                id="safe-chart"
            ),
            className="card",
            
        ),
     
     ]
 )


content = html.Div(
     [

         content_indicator_row,
         content_third_row,
         content_secu_row,
         content_con_row,
         content_safe_row
     ],
     style=CONTENT_STYLE
 )

# %%
app.layout = html.Div([sidebar, content])

# %%
@app.callback(
    Output("district-dropdown", "options"),
    [Input("region-dropdown", "value")],
)
def update_districts(region):
    district= (df[df['Regions'] == str(region)]['District']).unique()
#     values = [nr for nr in np.sort(district)]
    values = [{"label": nr, "value": nr} for nr in np.sort(district)]

    return values

# %%
@app.callback(
   [Output("eco-chart", "figure"),
    Output("type-chart", "figure"),
    Output("secu-chart", "figure"),
    Output("safe-chart", "figure"),
    Output("con-chart", "figure")],
    [Input("region-dropdown", "value"),
    Input("district-dropdown", "value"),
    Input("indicators-dropdown", "value")],
)
def submit_(region, district, indicators):   
    if district:
        if indicators == 'Age':
            
            x_bar = 'Age'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            
        elif indicators == 'Sex':
            
            x_bar = 'Sex'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            
            
        elif indicators == 'Education':
            
            x_bar = 'What is your level of education?'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['District'] == str(district)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            lab = district
        
    elif region:
        
        if indicators == 'Age':
            
            x_bar = 'Age'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            
        elif indicators == 'Sex':
            
            x_bar = 'Sex'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            
            
        elif indicators == 'Education':
            
            x_bar = 'What is your level of education?'
                
            c_bar = 'Are you engaged in any economic activity?'
            eco_result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar]
            ).count()
            
            c_bar_econ = 'What type of economic activity are you engaged in?'
            eco_type = result = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_econ]
            ).count()
            
            c_bar_secu = 'Would you describe the current security situation in the country as secured?'
            eco_secu = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_secu]
            ).count()
            
            c_bar_safe = 'Do you feel safe in the country?'
            eco_safe = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_safe]
            ).count()
            
            c_bar_con = 'Do you have confidence in the ability of security agencies to contain the security situation?'
            eco_con = df[df['Regions'] == str(region)].groupby(
                [x_bar, c_bar_con]
            ).count()
            
            
           
        lab = region
        
    else:
        pass
        
    
    eco_result = eco_result.reset_index()
    eco_result['count'] = eco_result['Regions']
    
    eco_type = eco_type.reset_index()
    eco_type['count'] = eco_type['Regions']
    
    eco_secu = eco_secu.reset_index()
    eco_secu['count'] = eco_secu['Regions']
    
    eco_safe = eco_safe.reset_index()
    eco_safe['count'] = eco_safe['Regions']
    
    eco_con = eco_con.reset_index()
    eco_con['count'] = eco_con['Regions']


    eco_chart_figure = px.bar(
        eco_result, x=x_bar, y="count", 
        color=c_bar)
    type_chart_figure = px.bar(
        eco_type, x=x_bar, y="count", 
        color=c_bar_econ)
    secu_chart_figure = px.bar(
        eco_secu, x=x_bar, y="count", 
        color=c_bar_secu)
    safe_chart_figure = px.bar(
        eco_safe, x=x_bar, y="count", 
        color=c_bar_safe)
    con_chart_figure = px.bar(
        eco_con, x=x_bar, y="count", 
        color=c_bar_con)
    
    return eco_chart_figure, type_chart_figure, secu_chart_figure, safe_chart_figure, con_chart_figure

# %%
if __name__ == '__main__':
    app.run_server()

# %%
import app
